# %% [markdown]
# <a href="https://colab.research.google.com/github/httppaulinaar/Probabilidad-y-estad-stica/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# #UNIDAD 1
# #Facilitador: José Gabriel Rodriguez Rivas
# #Practica 3
# ##**Tablas de frecuencia**

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [19, 70, 18, 47, 26, 40, 39, 67, 53, 64, 46, 36, 34, 60, 53, 22, 50, 44, 38, 22, 57, 63, 29, 69, 42, 56, 20, 60, 41, 51, 42, 23, 44, 50, 19, 45, 59, 38, 67, 41, 45, 56, 41, 42, 39, 39, 25, 47, 48, 41, 56, 35, 23, 56, 70, 23, 53, 47, 64, 21, 39, 60, 60, 55, 65, 29, 48, 42, 34, 63, 33, 54, 65, 51, 28, 31, 44, 32, 30, 33, 28, 67, 57, 21, 47, 46, 24, 70, 47, 66, 32, 54, 60, 21, 61, 38, 54, 27, 23, 38]

# %%
import pandas as pd #analisis de datos
df=pd.DataFrame(edades,columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      19
# 1      70
# 2      18
# 3      47
# 4      26

# %%
tabla_frecuencias=df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns=['Edades','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edades')
print("Tabla de Distribución de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edades  Frecuencia
# 31      18           1
# 18      19           2
# 35      20           1
# 10      21           3
# 29      22           2
# 7       23           4
# 42      24           1
# 37      25           1
# 32      26           1
# 45      27           1
# 15      28           2
# 23      29           2
# 41      30           1
# 40      31           1
# 16      32           2
# 14      33           2
# 19      34           2
# 39      35           1
# 30      36           1
# 5       38           4
# 2       39           4
# 33      40           1
# 4       41           4
# 6       42           4
# 8       44           3
# 22      45           2
# 20      46           2
# 0       47           5
# 17      48           2
# 28      50           2
# 26      51           2
# 11      53           3
# 9       54           3
# 38      55           1
# 3       56           4
# 25      57           2
# 34      59           1
# 1       60           5
# 44      61           1
# 24      63           2
# 21      64           2
# 27      65           2
# 43      66           1
# 12      67           3
# 36      69           1
# 13      70           3

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa
# 31      18           1           0.01
# 18      19           2           0.02
# 35      20           1           0.01
# 10      21           3           0.03
# 29      22           2           0.02
# 7       23           4           0.04
# 42      24           1           0.01
# 37      25           1           0.01
# 32      26           1           0.01
# 45      27           1           0.01
# 15      28           2           0.02
# 23      29           2           0.02
# 41      30           1           0.01
# 40      31           1           0.01
# 16      32           2           0.02
# 14      33           2           0.02
# 19      34           2           0.02
# 39      35           1           0.01
# 30      36           1           0.01
# 5       38           4           0.04
# 2       39           4           0.04
# 33      40           1           0.01
# 4       41           4           0.04
# 6       42           4           0.04
# 8       44           3           0.03
# 22      45           2           0.02
# 20      46           2           0.02
# 0       47           5           0.05
# 17      48           2           0.02
# 28      50           2           0.02
# 26      51           2           0.02
# 11      53           3           0.03
# 9       54           3           0.03
# 38      55           1           0.01
# 3       56           4           0.04
# 25      57           2           0.02
# 34      59           1           0.01
# 1       60           5           0.05
# 44      61           1           0.01
# 24      63           2           0.02
# 21      64           2           0.02
# 27      65           2           0.02
# 43      66           1           0.01
# 12      67           3           0.03
# 36      69           1           0.01
# 13      70           3           0.03

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual
# 31      18           1           0.01              1.0
# 18      19           2           0.02              2.0
# 35      20           1           0.01              1.0
# 10      21           3           0.03              3.0
# 29      22           2           0.02              2.0
# 7       23           4           0.04              4.0
# 42      24           1           0.01              1.0
# 37      25           1           0.01              1.0
# 32      26           1           0.01              1.0
# 45      27           1           0.01              1.0
# 15      28           2           0.02              2.0
# 23      29           2           0.02              2.0
# 41      30           1           0.01              1.0
# 40      31           1           0.01              1.0
# 16      32           2           0.02              2.0
# 14      33           2           0.02              2.0
# 19      34           2           0.02              2.0
# 39      35           1           0.01              1.0
# 30      36           1           0.01              1.0
# 5       38           4           0.04              4.0
# 2       39           4           0.04              4.0
# 33      40           1           0.01              1.0
# 4       41           4           0.04              4.0
# 6       42           4           0.04              4.0
# 8       44           3           0.03              3.0
# 22      45           2           0.02              2.0
# 20      46           2           0.02              2.0
# 0       47           5           0.05              5.0
# 17      48           2           0.02              2.0
# 28      50           2           0.02              2.0
# 26      51           2           0.02              2.0
# 11      53           3           0.03              3.0
# 9       54           3           0.03              3.0
# 38      55           1           0.01              1.0
# 3       56           4           0.04              4.0
# 25      57           2           0.02              2.0
# 34      59           1           0.01              1.0
# 1       60           5           0.05              5.0
# 44      61           1           0.01              1.0
# 24      63           2           0.02              2.0
# 21      64           2           0.02              2.0
# 27      65           2           0.02              2.0
# 43      66           1           0.01              1.0
# 12      67           3           0.03              3.0
# 36      69           1           0.01              1.0
# 13      70           3           0.03              3.0

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 31      18           1           0.01              1.0               1
# 18      19           2           0.02              2.0               3
# 35      20           1           0.01              1.0               4
# 10      21           3           0.03              3.0               7
# 29      22           2           0.02              2.0               9
# 7       23           4           0.04              4.0              13
# 42      24           1           0.01              1.0              14
# 37      25           1           0.01              1.0              15
# 32      26           1           0.01              1.0              16
# 45      27           1           0.01              1.0              17
# 15      28           2           0.02              2.0              19
# 23      29           2           0.02              2.0              21
# 41      30           1           0.01              1.0              22
# 40      31           1           0.01              1.0              23
# 16      32           2           0.02              2.0              25
# 14      33           2           0.02              2.0              27
# 19      34           2           0.02              2.0              29
# 39      35           1           0.01              1.0              30
# 30      36           1           0.01              1.0              31
# 5       38           4           0.04              4.0              35
# 2       39           4           0.04              4.0              39
# 33      40           1           0.01              1.0              40
# 4       41           4           0.04              4.0              44
# 6       42           4           0.04              4.0              48
# 8       44           3           0.03              3.0              51
# 22      45           2           0.02              2.0              53
# 20      46           2           0.02              2.0              55
# 0       47           5           0.05              5.0              60
# 17      48           2           0.02              2.0              62
# 28      50           2           0.02              2.0              64
# 26      51           2           0.02              2.0              66
# 11      53           3           0.03              3.0              69
# 9       54           3           0.03              3.0              72
# 38      55           1           0.01              1.0              73
# 3       56           4           0.04              4.0              77
# 25      57           2           0.02              2.0              79
# 34      59           1           0.01              1.0              80
# 1       60           5           0.05              5.0              85
# 44      61           1           0.01              1.0              86
# 24      63           2           0.02              2.0              88
# 21      64           2           0.02              2.0              90
# 27      65           2           0.02              2.0              92
# 43      66           1           0.01              1.0              93
# 12      67           3           0.03              3.0              96
# 36      69           1           0.01              1.0              97
# 13      70           3           0.03              3.0             100

# %% [markdown]
# #REGLA DE STURGES
# ##C=1+LOG2(N)

# %%
import math

# %%
print(edades)
# Out:
# [19, 70, 18, 47, 26, 40, 39, 67, 53, 64, 46, 36, 34, 60, 53, 22, 50, 44, 38, 22, 57, 63, 29, 69, 42, 56, 20, 60, 41, 51, 42, 23, 44, 50, 19, 45, 59, 38, 67, 41, 45, 56, 41, 42, 39, 39, 25, 47, 48, 41, 56, 35, 23, 56, 70, 23, 53, 47, 64, 21, 39, 60, 60, 55, 65, 29, 48, 42, 34, 63, 33, 54, 65, 51, 28, 31, 44, 32, 30, 33, 28, 67, 57, 21, 47, 46, 24, 70, 47, 66, 32, 54, 60, 21, 61, 38, 54, 27, 23, 38]

# %%
df=pd.DataFrame({'Edades':edades})
df
# Out:
#     Edades
# 0       19
# 1       70
# 2       18
# 3       47
# 4       26
# ..     ...
# 95      38
# 96      54
# 97      27
# 98      23
# 99      38
#
# [100 rows x 1 columns]

# %%
n= len(edades)

K= int(1 + math.log2(n))
print("Valor de n = ", n, " \nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut( df['Edades'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.286, 47.714]    20
# 1  (32.857, 40.286]    15
# 2  (17.947, 25.429]    15
# 3    (62.571, 70.0]    14
# 4  (47.714, 55.143]    13
# 5  (55.143, 62.571]    13
# 6  (25.429, 32.857]    10

# %%
tabla_frecuencia = tabla_frecuencia.sort_values (by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    15
# 6  (25.429, 32.857]    10
# 1  (32.857, 40.286]    15
# 0  (40.286, 47.714]    20
# 4  (47.714, 55.143]    13
# 5  (55.143, 62.571]    13
# 3    (62.571, 70.0]    14

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] /n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# %%
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    15      0.15       15.0       15         0.15
# 6  (25.429, 32.857]    10      0.10       10.0       25         0.25
# 1  (32.857, 40.286]    15      0.15       15.0       40         0.40
# 0  (40.286, 47.714]    20      0.20       20.0       60         0.60
# 4  (47.714, 55.143]    13      0.13       13.0       73         0.73
# 5  (55.143, 62.571]    13      0.13       13.0       86         0.86
# 3    (62.571, 70.0]    14      0.14       14.0      100         1.00
#
#    Frec Porc Ac
# 2          15.0
# 6          25.0
# 1          40.0
# 0          60.0
# 4          73.0
# 5          86.0
# 3         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la función de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estandar')

# %%
plt.hist(df['Edades'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
