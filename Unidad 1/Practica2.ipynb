# %% [markdown]
# <a href="https://colab.research.google.com/github/httppaulinaar/Probabilidad-y-estad-stica/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADÍSTICA
# #UNIDAD 1
# ##Facilitador: José Gabriel Rodriguez Rivas
# #Alumna: América Paulina Álvarez Rivera
# ###**PROGRAMA 2: MÁXIMO, MÍNIMO Y DISPERSIÓN DE DATOS**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
Fabrica1=[]
for _ in range(100):
  numero_aleatorio=round(random.uniform(50,1000),2)
  Fabrica1.append(numero_aleatorio)

print(Fabrica1)
# Out:
# [107.16, 301.43, 543.77, 120.66, 780.84, 178.42, 868.19, 995.21, 991.55, 653.2, 941.27, 148.16, 640.82, 551.07, 235.36, 198.0, 414.8, 88.2, 557.77, 267.42, 313.32, 192.79, 835.9, 804.26, 935.12, 422.53, 723.3, 775.06, 818.78, 190.32, 305.11, 668.98, 696.88, 576.25, 389.43, 190.55, 144.63, 139.94, 78.02, 996.71, 134.8, 589.98, 333.4, 490.68, 985.22, 920.1, 123.92, 650.03, 929.92, 573.33, 583.33, 421.73, 648.35, 158.28, 492.59, 843.02, 595.8, 136.17, 215.2, 931.1, 619.62, 451.1, 745.51, 278.92, 92.15, 742.97, 770.73, 920.63, 603.61, 201.73, 292.99, 980.14, 154.97, 93.07, 68.48, 492.45, 753.43, 760.48, 251.82, 337.88, 98.24, 642.04, 859.39, 390.74, 288.4, 655.78, 676.97, 993.21, 201.34, 209.66, 766.42, 573.0, 326.26, 744.37, 348.45, 995.28, 747.95, 847.87, 384.25, 863.94]

# %%
Fabrica2=[]
for _ in range(100):
  numero_aleatorio=round(random.uniform(50,1000),2)
  Fabrica2.append(numero_aleatorio)

print(Fabrica2)
# Out:
# [137.76, 801.24, 127.53, 581.37, 594.88, 643.15, 495.43, 91.2, 125.94, 514.83, 926.39, 938.95, 367.66, 810.18, 254.15, 196.88, 381.07, 648.63, 960.43, 216.7, 249.25, 400.5, 478.93, 329.76, 712.74, 855.34, 67.65, 890.69, 467.96, 815.35, 51.84, 230.62, 780.12, 100.21, 706.17, 87.63, 932.08, 817.81, 540.64, 813.21, 800.69, 329.28, 597.26, 640.8, 238.9, 786.28, 532.49, 175.81, 592.81, 413.81, 966.62, 461.42, 257.74, 147.62, 615.0, 548.75, 939.76, 377.6, 831.43, 60.76, 720.85, 774.27, 422.85, 580.54, 351.62, 97.03, 307.74, 96.33, 487.57, 466.81, 802.64, 605.08, 140.89, 371.49, 633.86, 98.69, 350.37, 269.41, 277.43, 685.25, 858.63, 827.86, 296.94, 949.05, 516.64, 255.49, 546.84, 201.75, 915.72, 914.72, 429.03, 453.88, 911.72, 321.8, 501.88, 959.03, 154.25, 126.56, 388.51, 331.57]

# %% [markdown]
# #MAXIMO, MINIMO, RANGO

# %%
maximo1=max(Fabrica1)
minimo1=min(Fabrica1)
rango1=maximo1-minimo1
media1=mean(Fabrica1)
mediana1=median(Fabrica1)
moda1= mode(Fabrica1)
desviacion_estandar_f1=stdev(Fabrica1)
print("Estadística descriptiva de la Fabrica 1 \n","Media=",media1,
      "\n Mediana=",mediana1,"\n Moda=",moda1,"\n Máximo=",maximo1,
      "\n Minimo=", minimo1,"\n Rango=", rango1)
print("Desviación Estandar=", desviacion_estandar_f1)
# Out:
# Estadística descriptiva de la Fabrica 1
#  Media= 517.6437
#  Mediana= 554.4200000000001
#  Moda= 107.16
#  Máximo= 996.71
#  Minimo= 68.48
#  Rango= 928.23
# Desviación Estandar= 293.1433260874381

# %%
  maximo2=max(Fabrica2)
  minimo2=min(Fabrica2)
  rango2=maximo2-minimo2
  media2=mean(Fabrica2)
  mediana2=median(Fabrica2)
  moda2= mode(Fabrica2)
  desviacion_estandar_f2=stdev(Fabrica2)
  print("Estadística descriptiva de la Fabrica 2 \n","Media=",media2,
          "\n Mediana=",mediana2,"\n Moda=",moda2,"\n Máximo=",maximo2,
          "\n Minimo=", minimo2,"\n Rango=", rango2)
  print("Desviación Estandar=", desviacion_estandar_f2)
# Out:
# Estadística descriptiva de la Fabrica 2
#  Media= 498.6029
#  Mediana= 483.25
#  Moda= 137.76
#  Máximo= 966.62
#  Minimo= 51.84
#  Rango= 914.78
# Desviación Estandar= 277.99536432911026

# %%
plt.figure(figsize=(8,6))
plt.hist(Fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1-desviacion_estandar_f1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion_estandar_f1:.2f}')
plt.axvline(media1+desviacion_estandar_f1, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fábrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(Fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2-desviacion_estandar_f2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion_estandar_f2:.2f}')
plt.axvline(media1+desviacion_estandar_f1, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fábrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(x=Fabrica1,kde=True,kde_kws={'bw_adjust':0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(x=Fabrica2,kde=True,kde_kws={'bw_adjust':0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
