# %% [markdown]
# <a href="https://colab.research.google.com/github/httppaulinaar/Probabilidad-y-estad-stica/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADÍSTICA
# #UNIDAD 1
# ##Facilitador: José Gabriel Rodriguez Rivas
# #Alumna: América Paulina Álvarez Rivera
# ###**PROGRAMA 2: MÁXIMO, MÍNIMO Y DISPERCIÓN DE DATOS**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
Fabrica1=[]
for _ in range(100):
  numero_aleatorio=round(random.uniform(50,1000),2)
  Fabrica1.append(numero_aleatorio)

print(Fabrica1)
# Out:
# [958.99, 570.91, 95.11, 894.14, 835.66, 654.62, 238.32, 732.15, 99.15, 160.47, 800.65, 624.2, 322.37, 435.22, 590.04, 875.68, 427.86, 262.84, 827.09, 73.37, 411.88, 908.03, 284.38, 391.53, 183.35, 408.79, 473.39, 80.28, 642.06, 902.4, 506.52, 775.16, 946.71, 692.71, 348.8, 906.62, 424.05, 239.81, 925.31, 538.93, 127.21, 995.57, 224.78, 840.9, 103.48, 271.32, 317.07, 287.46, 944.27, 730.19, 624.87, 534.36, 980.36, 302.23, 456.98, 295.68, 555.49, 450.09, 170.71, 718.2, 700.33, 900.93, 494.8, 812.93, 821.18, 781.34, 900.58, 620.1, 173.03, 360.62, 374.7, 597.71, 873.78, 773.68, 669.09, 526.06, 269.07, 141.94, 235.95, 162.61, 979.69, 636.06, 498.6, 470.73, 317.08, 650.02, 481.08, 855.44, 185.0, 237.67, 247.9, 967.63, 612.03, 862.6, 695.26, 525.35, 577.75, 390.38, 296.69, 338.28]

# %%
Fabrica2=[]
for _ in range(100):
  numero_aleatorio=round(random.uniform(50,1000),2)
  Fabrica2.append(numero_aleatorio)

print(Fabrica2)
# Out:
# [864.74, 572.28, 607.75, 483.14, 711.77, 257.16, 941.85, 645.85, 118.77, 562.58, 229.04, 331.71, 694.0, 426.0, 969.98, 377.86, 689.34, 615.44, 410.2, 764.8, 275.68, 647.82, 782.93, 263.65, 404.91, 433.64, 770.56, 995.57, 341.59, 529.12, 987.34, 874.96, 440.0, 70.64, 499.65, 636.95, 699.17, 209.28, 218.15, 883.08, 125.67, 841.22, 802.34, 114.49, 570.94, 98.08, 277.54, 697.83, 553.87, 780.66, 161.85, 460.45, 380.74, 134.31, 583.07, 109.29, 544.22, 355.27, 993.28, 123.69, 222.17, 229.99, 510.79, 987.47, 627.02, 333.93, 661.03, 619.46, 72.44, 479.74, 531.98, 706.81, 405.5, 744.19, 724.79, 823.98, 692.64, 385.41, 858.41, 629.06, 208.72, 83.23, 592.43, 548.0, 835.57, 421.05, 490.08, 625.03, 774.21, 267.8, 748.41, 563.39, 53.62, 386.01, 672.94, 157.83, 853.58, 507.87, 358.88, 503.12]

# %% [markdown]
# #MAXIMO, MINIMO, RANGO

# %%
maximo1=max(Fabrica1)
minimo1=min(Fabrica1)
rango1=maximo1-minimo1
media1=mean(Fabrica1)
mediana1=median(Fabrica1)
moda1= mode(Fabrica1)
desviacion_estandar_f1=stdev(Fabrica1)
print("Estadística descriptiva de la Fabrica 1 \n","Media=",media1,
      "\n Mediana=",mediana1,"\n Moda=",moda1,"\n Máximo=",maximo1,
      "\n Minimo=", minimo1,"\n Rango=", rango1)
print("Desviación Estandar=", desviacion_estandar_f1)
# Out:
# Estadística descriptiva de la Fabrica 1
#  Media= 534.1644
#  Mediana= 525.7049999999999
#  Moda= 958.99
#  Máximo= 995.57
#  Minimo= 73.37
#  Rango= 922.2
# Desviación Estandar= 270.15230632135547

# %%
if Fabrica2:
    maximo2=max(Fabrica2)
    minimo2=min(Fabrica2)
    rango2=maximo2-minimo2
    media2=mean(Fabrica2)
    mediana2=median(Fabrica2)
    moda2= mode(Fabrica2)
    desviacion_estandar_f2=stdev(Fabrica2)
    print("Estadística descriptiva de la Fabrica 2 \n","Media=",media2,
          "\n Mediana=",mediana2,"\n Moda=",moda2,"\n Máximo=",maximo2,
          "\n Minimo=", minimo2,"\n Rango=", rango2)
    print("Desviación Estandar=", desviacion_estandar_f2)
else:
    print("Error: La lista Fabrica2 está vacía. Por favor, asegúrese de que la lista se haya poblado correctamente en la celda anterior.")
# Out:
# Estadística descriptiva de la Fabrica 2
#  Media= 518.4634
#  Mediana= 538.1
#  Moda= 864.74
#  Máximo= 995.57
#  Minimo= 53.62
#  Rango= 941.95
# Desviación Estandar= 255.8605977781533
