# %% [markdown]
# <a href="https://colab.research.google.com/github/httppaulinaar/Probabilidad-y-estad-stica/blob/main/Unidad2/Ejemplo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #UNIDAD 2
# #PROBABILIDAD Y ESTADÍSTICA
# ##EJEMPLO 1
# ###Facilitador: José Gabriel Rodriguez Rivas
# ### Alumna: América Paulina Álvarez Rivera

# %%
import math as mt #  Para utilizar facctorial
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
nombres = ["Oscar", "Paco" , "Paty", "Laura", "Rubén","Luis","Lucy","Alberto","Juan", "Danny"]
n = len(nombres)
r = 2 # ¿Cómo agrupar?

Cn = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n-r))
print("Exsiten", Cn , "posibles combinacioners sin repetición del total de ", n ," nombres", "en grupos de",r, "en",r)
print("Aqui las combinaciones ")
combinaciones_nombres = list (combinations (nombres,r))

for combinacion in combinaciones_nombres:
    print(combinacion)
