# %% [markdown]
# <a href="https://colab.research.google.com/github/httppaulinaar/Probabilidad-y-estad-stica/blob/main/Unidad4/Ej2_D_Binomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##PROBABILIDAD Y ESTADÍSTICA
# ###Ejercicio 2
# ###Distribución binomial
# ####Facilitador: José Gabriel Rodriguez Rivas
# ####Alumna: América Paulina Álvarez Rivera

# %%
from scipy.stats import binom

# Parámetros de la distribución binomial
n = 10
p = 0.10
x = 2

# Calcular la probabilidad de la variable aleatoria X = 2
probabilidad_x_2 = binom.pmf(x, n, p)

print("La probabilidad de que la variable aleatoria X sea igual a 2 es:", probabilidad_x_2)
# Out:
# La probabilidad de que la variable aleatoria X sea igual a 2 es: 0.19371024450000007
