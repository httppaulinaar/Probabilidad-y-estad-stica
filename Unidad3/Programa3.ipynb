# %% [markdown]
# <a href="https://colab.research.google.com/github/httppaulinaar/Probabilidad-y-estad-stica/blob/main/Unidad3/Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#UNIDAD 3
##PROBABILIDAD Y ESTADÍSTICA
###Programa
##Varianza y desviación
####Facilitador: José Gabriel Rodriguez Rivas
####Alumna: América Paulina Álvarez Rivera

# %%
import math

# Definición de los datos
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

# Calcular E(X) - Esperanza matemática
esperanza = 0
for i in range(len(x)):
    esperanza += x[i] * p[i]

# Calcular E(X^2) - Esperanza del cuadrado
esperanza_cuadrado = 0
for i in range(len(x)):
    esperanza_cuadrado += (x[i] ** 2) * p[i]

# Calcular varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza**2
desviacion = math.sqrt(varianza)

# Mostrar resultados
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")
