# %% [markdown]
# <a href="https://colab.research.google.com/github/httppaulinaar/Probabilidad-y-estad-stica/blob/main/Unidad3/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #UNIDAD 3
# ##PROBABILIDAD Y ESTADÍSTICA
# ###PROGRAMA 1
# ####Facilitador: José Gabriel Rodriguez Rivas
# ####Alumna: América Paulina Álvarez Rivera

# %%
import matplotlib.pyplot as plt
# Valores de la variable aleatoria
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
# Graficar distribución
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Calificación")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
